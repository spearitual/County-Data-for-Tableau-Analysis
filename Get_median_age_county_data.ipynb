# %% [markdown]
# ## Get median age county data, 2000-2022

# %% [markdown]
# ### Concatenating 2000-2009 data

# %%
import pandas as pd
pd.options.mode.copy_on_write = True

# %% [markdown]
# Data from US Census here: https://www2.census.gov/programs-surveys/popest/datasets/2000-2009/counties/asrh/ \
# Unlike the 2010-2019 and 2020-2022 data, a combined dataframe for the entire United States is not provided.\
# Here I create one by concatenating all of the states.

# %%
dfs = []
for i in range(1,57):
    if i in [3,7,14,43,52]: #These state codes are reserved and do not currently refer to any existing data
        continue
    #Specifying the encoding is necessary due to a New Mexican county having a non-standard character in its name.
    current_df = pd.read_csv(f'https://www2.census.gov/programs-surveys/popest/datasets/2000-2009/counties/asrh/cc-est2009-agesex-{i:02d}.csv',engine='python',encoding='latin1')
    dfs.append(current_df)
df1 = pd.concat(dfs)
df1
# Out:
#      SUMLEV  STATE  COUNTY   STNAME         CTYNAME  YEAR POPESTIMATE  \
# 0        50      1       1  Alabama  Autauga County     1       43671
# 1        50      1       1  Alabama  Autauga County     2       43671
# 2        50      1       1  Alabama  Autauga County     3       43872
# 3        50      1       1  Alabama  Autauga County     4       44434
# 4        50      1       1  Alabama  Autauga County     5       45157
# ..      ...    ...     ...      ...             ...   ...         ...
# 271      50     56      45  Wyoming   Weston County     8        6475
# 272      50     56      45  Wyoming   Weston County     9        6568
# 273      50     56      45  Wyoming   Weston County    10        6845
# 274      50     56      45  Wyoming   Weston County    11        6928
# 275      50     56      45  Wyoming   Weston County    12        7009
#
#     POPEST_MALE POPEST_FEM UNDER5_TOT  ... AGE4564_FEM AGE65PLUS_TOT  \
# 0         21221      22450       3023  ...        5078          4451
# 1         21221      22450       3023  ...        5078          4451
# 2         21318      22554       3027  ...        5126          4490
# 3         21591      22843       3096  ...        5307          4615
# 4         21928      23229       3106  ...        5453          4723
# ..          ...        ...        ...  ...         ...           ...
# 271        3325       3150        326  ...         931          1110
# 272        3370       3198        350  ...         978          1130
# 273        3553       3292        373  ...         996          1135
# 274        3590       3338        395  ...         992          1135
# 275        3642       3367        410  ...         989          1132
#
#     AGE65PLUS_MALE AGE65PLUS_FEM AGE85PLUS_TOT AGE85PLUS_MALE AGE85PLUS_FEM  \
# 0             1817          2634           428            113           315
# 1             1817          2634           428            113           315
# 2             1833          2657           434            115           319
# 3             1894          2721           431            113           318
# 4             1937          2786           422            111           311
# ..             ...           ...           ...            ...           ...
# 271            501           609           163             52           111
# 272            509           621           152             48           104
# 273            508           627           157             48           109
# 274            503           632           161             47           114
# 275            505           627           169             51           118
#
#     MEDIAN_AGE_TOT MEDIAN_AGE_MALE MEDIAN_AGE_FEM
# 0             35.1            33.9           36.1
# 1             35.1            33.9           36.1
# 2             35.2            34.0           36.1
# 3             35.6            34.3           36.6
# 4             35.9            34.6           36.9
# ..             ...             ...            ...
# 271           43.7            42.7           44.5
# 272           44.0            42.6           45.0
# 273           42.9            40.8           44.5
# 274           42.1            40.1           44.1
# 275           41.3            39.5           43.2
#
# [37716 rows x 45 columns]

# %% [markdown]
# ### Cleaning YEAR column

# %% [markdown]
# This must be done now, before concatenating with the subsequent dataframes, because they make use of the same number code. The key for the YEAR code can be found here: https://www2.census.gov/programs-surveys/popest/technical-documentation/file-layouts/2000-2009/cc-est2009-agesex.pdf

# %%
# The first two year codes refer to the census data from April rather than July, and an estimate of that data.
# For consistency, I've chosen to remove these rows.
df1 = df1[df1.YEAR >= 3]
df1.head()
# Out:
#      SUMLEV  STATE  COUNTY   STNAME         CTYNAME  YEAR POPESTIMATE  \
# 2        50      1       1  Alabama  Autauga County     3       43872
# 3        50      1       1  Alabama  Autauga County     4       44434
# 4        50      1       1  Alabama  Autauga County     5       45157
# 5        50      1       1  Alabama  Autauga County     6       45762
# 6        50      1       1  Alabama  Autauga County     7       46933
# ..      ...    ...     ...      ...             ...   ...         ...
# 271      50     56      45  Wyoming   Weston County     8        6475
# 272      50     56      45  Wyoming   Weston County     9        6568
# 273      50     56      45  Wyoming   Weston County    10        6845
# 274      50     56      45  Wyoming   Weston County    11        6928
# 275      50     56      45  Wyoming   Weston County    12        7009
#
#     POPEST_MALE POPEST_FEM UNDER5_TOT  ... AGE4564_FEM AGE65PLUS_TOT  \
# 2         21318      22554       3027  ...        5126          4490
# 3         21591      22843       3096  ...        5307          4615
# 4         21928      23229       3106  ...        5453          4723
# 5         22222      23540       3110  ...        5635          4866
# 6         22765      24168       3237  ...        5829          5037
# ..          ...        ...        ...  ...         ...           ...
# 271        3325       3150        326  ...         931          1110
# 272        3370       3198        350  ...         978          1130
# 273        3553       3292        373  ...         996          1135
# 274        3590       3338        395  ...         992          1135
# 275        3642       3367        410  ...         989          1132
#
#     AGE65PLUS_MALE AGE65PLUS_FEM AGE85PLUS_TOT AGE85PLUS_MALE AGE85PLUS_FEM  \
# 2             1833          2657           434            115           319
# 3             1894          2721           431            113           318
# 4             1937          2786           422            111           311
# 5             2053          2813           413            103           310
# 6             2133          2904           429            113           316
# ..             ...           ...           ...            ...           ...
# 271            501           609           163             52           111
# 272            509           621           152             48           104
# 273            508           627           157             48           109
# 274            503           632           161             47           114
# 275            505           627           169             51           118
#
#     MEDIAN_AGE_TOT MEDIAN_AGE_MALE MEDIAN_AGE_FEM
# 2             35.2            34.0           36.1
# 3             35.6            34.3           36.6
# 4             35.9            34.6           36.9
# 5             35.9            34.9           37.0
# 6             35.8            34.8           36.8
# ..             ...             ...            ...
# 271           43.7            42.7           44.5
# 272           44.0            42.6           45.0
# 273           42.9            40.8           44.5
# 274           42.1            40.1           44.1
# 275           41.3            39.5           43.2
#
# [31430 rows x 45 columns]

# %%
year_replacements = dict(zip(list(range(3,13)), [f'200{i}-07-01' for i in range(0,10)]))
year_replacements
# Out:
# {3: '2000-07-01',
#  4: '2001-07-01',
#  5: '2002-07-01',
#  6: '2003-07-01',
#  7: '2004-07-01',
#  8: '2005-07-01',
#  9: '2006-07-01',
#  10: '2007-07-01',
#  11: '2008-07-01',
#  12: '2009-07-01'}

# %%
for code, date in year_replacements.items():
    df1['YEAR'] = df1.YEAR.replace(code, date)
df1.head()
# Out:
#      SUMLEV  STATE  COUNTY   STNAME         CTYNAME        YEAR POPESTIMATE  \
# 2        50      1       1  Alabama  Autauga County  2000-07-01       43872
# 3        50      1       1  Alabama  Autauga County  2001-07-01       44434
# 4        50      1       1  Alabama  Autauga County  2002-07-01       45157
# 5        50      1       1  Alabama  Autauga County  2003-07-01       45762
# 6        50      1       1  Alabama  Autauga County  2004-07-01       46933
# ..      ...    ...     ...      ...             ...         ...         ...
# 271      50     56      45  Wyoming   Weston County  2005-07-01        6475
# 272      50     56      45  Wyoming   Weston County  2006-07-01        6568
# 273      50     56      45  Wyoming   Weston County  2007-07-01        6845
# 274      50     56      45  Wyoming   Weston County  2008-07-01        6928
# 275      50     56      45  Wyoming   Weston County  2009-07-01        7009
#
#     POPEST_MALE POPEST_FEM UNDER5_TOT  ... AGE4564_FEM AGE65PLUS_TOT  \
# 2         21318      22554       3027  ...        5126          4490
# 3         21591      22843       3096  ...        5307          4615
# 4         21928      23229       3106  ...        5453          4723
# 5         22222      23540       3110  ...        5635          4866
# 6         22765      24168       3237  ...        5829          5037
# ..          ...        ...        ...  ...         ...           ...
# 271        3325       3150        326  ...         931          1110
# 272        3370       3198        350  ...         978          1130
# 273        3553       3292        373  ...         996          1135
# 274        3590       3338        395  ...         992          1135
# 275        3642       3367        410  ...         989          1132
#
#     AGE65PLUS_MALE AGE65PLUS_FEM AGE85PLUS_TOT AGE85PLUS_MALE AGE85PLUS_FEM  \
# 2             1833          2657           434            115           319
# 3             1894          2721           431            113           318
# 4             1937          2786           422            111           311
# 5             2053          2813           413            103           310
# 6             2133          2904           429            113           316
# ..             ...           ...           ...            ...           ...
# 271            501           609           163             52           111
# 272            509           621           152             48           104
# 273            508           627           157             48           109
# 274            503           632           161             47           114
# 275            505           627           169             51           118
#
#     MEDIAN_AGE_TOT MEDIAN_AGE_MALE MEDIAN_AGE_FEM
# 2             35.2            34.0           36.1
# 3             35.6            34.3           36.6
# 4             35.9            34.6           36.9
# 5             35.9            34.9           37.0
# 6             35.8            34.8           36.8
# ..             ...             ...            ...
# 271           43.7            42.7           44.5
# 272           44.0            42.6           45.0
# 273           42.9            40.8           44.5
# 274           42.1            40.1           44.1
# 275           41.3            39.5           43.2
#
# [31430 rows x 45 columns]

# %% [markdown]
# ## Importing and cleaning YEAR column for 2010-2019 data

# %% [markdown]
# Data from: https://www2.census.gov/programs-surveys/popest/technical-documentation/file-layouts/2010-2020/ \
# \
# Year codes from: https://www2.census.gov/programs-surveys/popest/technical-documentation/file-layouts/2010-2020/cc-est2020-agesex.pdf

# %%
df2 = pd.read_csv('CC-EST2020-AGESEX-ALL.csv',engine='python',encoding='latin1')
df2
# Out:
#        SUMLEV  STATE  COUNTY   STNAME         CTYNAME  YEAR POPESTIMATE  \
# 0          50      1       1  Alabama  Autauga County     1       54571
# 1          50      1       1  Alabama  Autauga County     2       54582
# 2          50      1       1  Alabama  Autauga County     3       54761
# 3          50      1       1  Alabama  Autauga County     4       55229
# 4          50      1       1  Alabama  Autauga County     5       54970
# ...       ...    ...     ...      ...             ...   ...         ...
# 43997      50     56      45  Wyoming   Weston County    10        6962
# 43998      50     56      45  Wyoming   Weston County    11        6895
# 43999      50     56      45  Wyoming   Weston County    12        6880
# 44000      50     56      45  Wyoming   Weston County    13        6752
# 44001      50     56      45  Wyoming   Weston County    14        6743
#
#       POPEST_MALE POPEST_FEM UNDER5_TOT  ... AGE7579_FEM AGE8084_TOT  \
# 0           26569      28002       3579  ...         705         731
# 1           26576      28006       3582  ...         704         730
# 2           26667      28094       3575  ...         707         743
# 3           26980      28249       3552  ...         727         782
# 4           26830      28140       3405  ...         751         834
# ...           ...        ...        ...  ...         ...         ...
# 43997        3665       3297        373  ...         123         182
# 43998        3624       3271        351  ...         116         195
# 43999        3615       3265        333  ...         112         193
# 44000        3551       3201        318  ...         115         184
# 44001        3538       3205        321  ...         115         182
#
#       AGE8084_MALE AGE8084_FEM AGE85PLUS_TOT AGE85PLUS_MALE AGE85PLUS_FEM  \
# 0              295         436           551            159           392
# 1              294         436           551            159           392
# 2              299         444           556            164           392
# 3              315         467           601            191           410
# 4              340         494           632            206           426
# ...            ...         ...           ...            ...           ...
# 43997           91          91           195             66           129
# 43998           86         109           188             65           123
# 43999           81         112           195             73           122
# 44000           74         110           202             80           122
# 44001           72         110           202             81           121
#
#       MEDIAN_AGE_TOT MEDIAN_AGE_MALE MEDIAN_AGE_FEM
# 0                 37            35.9           37.9
# 1                 37            35.9           37.8
# 2               37.1              36           37.9
# 3               37.3            36.2           38.4
# 4               37.7            36.4           38.8
# ...              ...             ...            ...
# 43997           43.6            42.9           44.5
# 43998           43.8            43.2           44.6
# 43999           44.3            43.8           44.9
# 44000           44.6            43.9           45.3
# 44001           44.5            43.7           45.3
#
# [44002 rows x 96 columns]

# %%
# Year codes 13 and 14 overlap with data in the next dataframe, and so are unneeded here.
df2 = df2[(df2.YEAR >= 3) & (df2.YEAR <= 12)]
df2.head()
# Out:
#        SUMLEV  STATE  COUNTY   STNAME         CTYNAME  YEAR POPESTIMATE  \
# 2          50      1       1  Alabama  Autauga County     3       54761
# 3          50      1       1  Alabama  Autauga County     4       55229
# 4          50      1       1  Alabama  Autauga County     5       54970
# 5          50      1       1  Alabama  Autauga County     6       54747
# 6          50      1       1  Alabama  Autauga County     7       54922
# ...       ...    ...     ...      ...             ...   ...         ...
# 43995      50     56      45  Wyoming   Weston County     8        7202
# 43996      50     56      45  Wyoming   Weston County     9        7228
# 43997      50     56      45  Wyoming   Weston County    10        6962
# 43998      50     56      45  Wyoming   Weston County    11        6895
# 43999      50     56      45  Wyoming   Weston County    12        6880
#
#       POPEST_MALE POPEST_FEM UNDER5_TOT  ... AGE7579_FEM AGE8084_TOT  \
# 2           26667      28094       3575  ...         707         743
# 3           26980      28249       3552  ...         727         782
# 4           26830      28140       3405  ...         751         834
# 5           26588      28159       3217  ...         794         890
# 6           26804      28118       3183  ...         822         944
# ...           ...        ...        ...  ...         ...         ...
# 43995        3796       3406        440  ...         138         164
# 43996        3794       3434        448  ...         131         172
# 43997        3665       3297        373  ...         123         182
# 43998        3624       3271        351  ...         116         195
# 43999        3615       3265        333  ...         112         193
#
#       AGE8084_MALE AGE8084_FEM AGE85PLUS_TOT AGE85PLUS_MALE AGE85PLUS_FEM  \
# 2              299         444           556            164           392
# 3              315         467           601            191           410
# 4              340         494           632            206           426
# 5              378         512           636            209           427
# 6              400         544           668            232           436
# ...            ...         ...           ...            ...           ...
# 43995           74          90           187             71           116
# 43996           86          86           193             71           122
# 43997           91          91           195             66           129
# 43998           86         109           188             65           123
# 43999           81         112           195             73           122
#
#       MEDIAN_AGE_TOT MEDIAN_AGE_MALE MEDIAN_AGE_FEM
# 2               37.1              36           37.9
# 3               37.3            36.2           38.4
# 4               37.7            36.4           38.8
# 5               38.1            36.8           39.1
# 6               38.2            36.8           39.5
# ...              ...             ...            ...
# 43995           42.3            41.3           43.6
# 43996           42.3            41.7             43
# 43997           43.6            42.9           44.5
# 43998           43.8            43.2           44.6
# 43999           44.3            43.8           44.9
#
# [31430 rows x 96 columns]

# %%
year_replacements2 = dict(zip(list(range(3,13)), [f'201{i}-07-01' for i in range(0,10)]))
year_replacements2
# Out:
# {3: '2010-07-01',
#  4: '2011-07-01',
#  5: '2012-07-01',
#  6: '2013-07-01',
#  7: '2014-07-01',
#  8: '2015-07-01',
#  9: '2016-07-01',
#  10: '2017-07-01',
#  11: '2018-07-01',
#  12: '2019-07-01'}

# %%
for code, date in year_replacements2.items():
    df2['YEAR'] = df2.YEAR.replace(code, date)
df2.head()
# Out:
#        SUMLEV  STATE  COUNTY   STNAME         CTYNAME        YEAR POPESTIMATE  \
# 2          50      1       1  Alabama  Autauga County  2010-07-01       54761
# 3          50      1       1  Alabama  Autauga County  2011-07-01       55229
# 4          50      1       1  Alabama  Autauga County  2012-07-01       54970
# 5          50      1       1  Alabama  Autauga County  2013-07-01       54747
# 6          50      1       1  Alabama  Autauga County  2014-07-01       54922
# ...       ...    ...     ...      ...             ...         ...         ...
# 43995      50     56      45  Wyoming   Weston County  2015-07-01        7202
# 43996      50     56      45  Wyoming   Weston County  2016-07-01        7228
# 43997      50     56      45  Wyoming   Weston County  2017-07-01        6962
# 43998      50     56      45  Wyoming   Weston County  2018-07-01        6895
# 43999      50     56      45  Wyoming   Weston County  2019-07-01        6880
#
#       POPEST_MALE POPEST_FEM UNDER5_TOT  ... AGE7579_FEM AGE8084_TOT  \
# 2           26667      28094       3575  ...         707         743
# 3           26980      28249       3552  ...         727         782
# 4           26830      28140       3405  ...         751         834
# 5           26588      28159       3217  ...         794         890
# 6           26804      28118       3183  ...         822         944
# ...           ...        ...        ...  ...         ...         ...
# 43995        3796       3406        440  ...         138         164
# 43996        3794       3434        448  ...         131         172
# 43997        3665       3297        373  ...         123         182
# 43998        3624       3271        351  ...         116         195
# 43999        3615       3265        333  ...         112         193
#
#       AGE8084_MALE AGE8084_FEM AGE85PLUS_TOT AGE85PLUS_MALE AGE85PLUS_FEM  \
# 2              299         444           556            164           392
# 3              315         467           601            191           410
# 4              340         494           632            206           426
# 5              378         512           636            209           427
# 6              400         544           668            232           436
# ...            ...         ...           ...            ...           ...
# 43995           74          90           187             71           116
# 43996           86          86           193             71           122
# 43997           91          91           195             66           129
# 43998           86         109           188             65           123
# 43999           81         112           195             73           122
#
#       MEDIAN_AGE_TOT MEDIAN_AGE_MALE MEDIAN_AGE_FEM
# 2               37.1              36           37.9
# 3               37.3            36.2           38.4
# 4               37.7            36.4           38.8
# 5               38.1            36.8           39.1
# 6               38.2            36.8           39.5
# ...              ...             ...            ...
# 43995           42.3            41.3           43.6
# 43996           42.3            41.7             43
# 43997           43.6            42.9           44.5
# 43998           43.8            43.2           44.6
# 43999           44.3            43.8           44.9
#
# [31430 rows x 96 columns]

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 31430 entries, 2 to 43999
# Data columns (total 96 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   SUMLEV           31430 non-null  int64
#  1   STATE            31430 non-null  int64
#  2   COUNTY           31430 non-null  int64
#  3   STNAME           31430 non-null  object
#  4   CTYNAME          31430 non-null  object
#  5   YEAR             31430 non-null  object
#  6   POPESTIMATE      31430 non-null  object
#  7   POPEST_MALE      31430 non-null  object
#  8   POPEST_FEM       31430 non-null  object
#  9   UNDER5_TOT       31430 non-null  object
#  10  UNDER5_MALE      31430 non-null  object
#  11  UNDER5_FEM       31430 non-null  object
#  12  AGE513_TOT       31430 non-null  object
#  13  AGE513_MALE      31430 non-null  object
#  14  AGE513_FEM       31430 non-null  object
#  15  AGE1417_TOT      31430 non-null  object
#  16  AGE1417_MALE     31430 non-null  object
#  17  AGE1417_FEM      31430 non-null  object
#  18  AGE1824_TOT      31430 non-null  object
#  19  AGE1824_MALE     31430 non-null  object
#  20  AGE1824_FEM      31430 non-null  object
#  21  AGE16PLUS_TOT    31430 non-null  object
#  22  AGE16PLUS_MALE   31430 non-null  object
#  23  AGE16PLUS_FEM    31430 non-null  object
#  24  AGE18PLUS_TOT    31430 non-null  object
#  25  AGE18PLUS_MALE   31430 non-null  object
#  26  AGE18PLUS_FEM    31430 non-null  object
#  27  AGE1544_TOT      31430 non-null  object
#  28  AGE1544_MALE     31430 non-null  object
#  29  AGE1544_FEM      31430 non-null  object
#  30  AGE2544_TOT      31430 non-null  object
#  31  AGE2544_MALE     31430 non-null  object
#  32  AGE2544_FEM      31430 non-null  object
#  33  AGE4564_TOT      31430 non-null  object
#  34  AGE4564_MALE     31430 non-null  object
#  35  AGE4564_FEM      31430 non-null  object
#  36  AGE65PLUS_TOT    31430 non-null  object
#  37  AGE65PLUS_MALE   31430 non-null  object
#  38  AGE65PLUS_FEM    31430 non-null  object
#  39  AGE04_TOT        31430 non-null  object
#  40  AGE04_MALE       31430 non-null  object
#  41  AGE04_FEM        31430 non-null  object
#  42  AGE59_TOT        31430 non-null  object
#  43  AGE59_MALE       31430 non-null  object
#  44  AGE59_FEM        31430 non-null  object
#  45  AGE1014_TOT      31430 non-null  object
#  46  AGE1014_MALE     31430 non-null  object
#  47  AGE1014_FEM      31430 non-null  object
#  48  AGE1519_TOT      31430 non-null  object
#  49  AGE1519_MALE     31430 non-null  object
#  50  AGE1519_FEM      31430 non-null  object
#  51  AGE2024_TOT      31430 non-null  object
#  52  AGE2024_MALE     31430 non-null  object
#  53  AGE2024_FEM      31430 non-null  object
#  54  AGE2529_TOT      31430 non-null  object
#  55  AGE2529_MALE     31430 non-null  object
#  56  AGE2529_FEM      31430 non-null  object
#  57  AGE3034_TOT      31430 non-null  object
#  58  AGE3034_MALE     31430 non-null  object
#  59  AGE3034_FEM      31430 non-null  object
#  60  AGE3539_TOT      31430 non-null  object
#  61  AGE3539_MALE     31430 non-null  object
#  62  AGE3539_FEM      31430 non-null  object
#  63  AGE4044_TOT      31430 non-null  object
#  64  AGE4044_MALE     31430 non-null  object
#  65  AGE4044_FEM      31430 non-null  object
#  66  AGE4549_TOT      31430 non-null  object
#  67  AGE4549_MALE     31430 non-null  object
#  68  AGE4549_FEM      31430 non-null  object
#  69  AGE5054_TOT      31430 non-null  object
#  70  AGE5054_MALE     31430 non-null  object
#  71  AGE5054_FEM      31430 non-null  object
#  72  AGE5559_TOT      31430 non-null  object
#  73  AGE5559_MALE     31430 non-null  object
#  74  AGE5559_FEM      31430 non-null  object
#  75  AGE6064_TOT      31430 non-null  object
#  76  AGE6064_MALE     31430 non-null  object
#  77  AGE6064_FEM      31430 non-null  object
#  78  AGE6569_TOT      31430 non-null  object
#  79  AGE6569_MALE     31430 non-null  object
#  80  AGE6569_FEM      31430 non-null  object
#  81  AGE7074_TOT      31430 non-null  object
#  82  AGE7074_MALE     31430 non-null  object
#  83  AGE7074_FEM      31430 non-null  object
#  84  AGE7579_TOT      31430 non-null  object
#  85  AGE7579_MALE     31430 non-null  object
#  86  AGE7579_FEM      31430 non-null  object
#  87  AGE8084_TOT      31430 non-null  object
#  88  AGE8084_MALE     31430 non-null  object
#  89  AGE8084_FEM      31430 non-null  object
#  90  AGE85PLUS_TOT    31430 non-null  object
#  91  AGE85PLUS_MALE   31430 non-null  object
#  92  AGE85PLUS_FEM    31430 non-null  object
#  93  MEDIAN_AGE_TOT   31430 non-null  object
#  94  MEDIAN_AGE_MALE  31430 non-null  object
#  95  MEDIAN_AGE_FEM   31430 non-null  object
# dtypes: int64(3), object(93)
# memory usage: 23.3+ MB

# %% [markdown]
# ## Importing and cleaning YEAR column for 2020-2022 data

# %% [markdown]
# Data from: https://www.census.gov/data/tables/time-series/demo/popest/2020s-counties-detail.html \
# \
# Year codes from: https://www2.census.gov/programs-surveys/popest/technical-documentation/file-layouts/2020-2022/cc-est2022-agesex.pdf

# %%
df3 = pd.read_csv('cc-est2022-agesex-all.csv',engine='python',encoding='latin1')
df3
# Out:
#        SUMLEV  STATE  COUNTY   STNAME          CTYNAME  YEAR  POPESTIMATE  \
# 0          50      1       1  Alabama   Autauga County     1        58802
# 1          50      1       1  Alabama   Autauga County     2        58902
# 2          50      1       1  Alabama   Autauga County     3        59210
# 3          50      1       1  Alabama   Autauga County     4        59759
# 4          50      1       3  Alabama   Baldwin County     1       231761
# ...       ...    ...     ...      ...              ...   ...          ...
# 12571      50     56      43  Wyoming  Washakie County     4         7719
# 12572      50     56      45  Wyoming    Weston County     1         6840
# 12573      50     56      45  Wyoming    Weston County     2         6818
# 12574      50     56      45  Wyoming    Weston County     3         6766
# 12575      50     56      45  Wyoming    Weston County     4         6860
#
#        POPEST_MALE  POPEST_FEM  UNDER5_TOT  ...  AGE7579_FEM  AGE8084_TOT  \
# 0            28761       30041        3443  ...         1055         1165
# 1            28819       30083        3457  ...         1064         1170
# 2            28851       30359        3416  ...         1074         1190
# 3            29105       30654        3460  ...         1152         1225
# 4           113388      118373       12046  ...         4861         5601
# ...            ...         ...         ...  ...          ...          ...
# 12571         3973        3746         378  ...          187          250
# 12572         3724        3116         308  ...          109          175
# 12573         3724        3094         310  ...          110          171
# 12574         3729        3037         302  ...          115          151
# 12575         3800        3060         296  ...          127          141
#
#        AGE8084_MALE  AGE8084_FEM  AGE85PLUS_TOT  AGE85PLUS_MALE  \
# 0               501          664            955             345
# 1               501          669            958             350
# 2               492          698            972             362
# 3               495          730           1019             385
# 4              2542         3059           4610            1812
# ...             ...          ...            ...             ...
# 12571           125          125            212              73
# 12572            70          105            191              73
# 12573            70          101            193              73
# 12574            66           85            184              69
# 12575            71           70            170              58
#
#        AGE85PLUS_FEM  MEDIAN_AGE_TOT  MEDIAN_AGE_MALE  MEDIAN_AGE_FEM
# 0                610            39.2             37.9            40.3
# 1                608            39.1             37.9            40.3
# 2                610            39.2             38.0            40.3
# 3                634            39.2             38.0            40.4
# 4               2798            43.7             42.5            44.9
# ...              ...             ...              ...             ...
# 12571            139            44.8             43.3            46.6
# 12572            118            43.5             42.7            44.8
# 12573            120            43.5             42.6            44.8
# 12574            115            43.9             43.1            45.3
# 12575            112            44.5             43.6            46.0
#
# [12576 rows x 96 columns]

# %%
# Unlie the previous two dataframes, only the first year needs to be removed for consistency.
df3 = df3[df3.YEAR != 1]
df3.head()
# Out:
#        SUMLEV  STATE  COUNTY   STNAME          CTYNAME  YEAR  POPESTIMATE  \
# 1          50      1       1  Alabama   Autauga County     2        58902
# 2          50      1       1  Alabama   Autauga County     3        59210
# 3          50      1       1  Alabama   Autauga County     4        59759
# 5          50      1       3  Alabama   Baldwin County     2       233219
# 6          50      1       3  Alabama   Baldwin County     3       239361
# ...       ...    ...     ...      ...              ...   ...          ...
# 12570      50     56      43  Wyoming  Washakie County     3         7712
# 12571      50     56      43  Wyoming  Washakie County     4         7719
# 12573      50     56      45  Wyoming    Weston County     2         6818
# 12574      50     56      45  Wyoming    Weston County     3         6766
# 12575      50     56      45  Wyoming    Weston County     4         6860
#
#        POPEST_MALE  POPEST_FEM  UNDER5_TOT  ...  AGE7579_FEM  AGE8084_TOT  \
# 1            28819       30083        3457  ...         1064         1170
# 2            28851       30359        3416  ...         1074         1190
# 3            29105       30654        3460  ...         1152         1225
# 5           114050      119169       12046  ...         4934         5653
# 6           116853      122508       12273  ...         5105         5836
# ...            ...         ...         ...  ...          ...          ...
# 12570         3968        3744         370  ...          171          241
# 12571         3973        3746         378  ...          187          250
# 12573         3724        3094         310  ...          110          171
# 12574         3729        3037         302  ...          115          151
# 12575         3800        3060         296  ...          127          141
#
#        AGE8084_MALE  AGE8084_FEM  AGE85PLUS_TOT  AGE85PLUS_MALE  \
# 1               501          669            958             350
# 2               492          698            972             362
# 3               495          730           1019             385
# 5              2561         3092           4667            1844
# 6              2653         3183           4725            1875
# ...             ...          ...            ...             ...
# 12570           117          124            218              78
# 12571           125          125            212              73
# 12573            70          101            193              73
# 12574            66           85            184              69
# 12575            71           70            170              58
#
#        AGE85PLUS_FEM  MEDIAN_AGE_TOT  MEDIAN_AGE_MALE  MEDIAN_AGE_FEM
# 1                608            39.1             37.9            40.3
# 2                610            39.2             38.0            40.3
# 3                634            39.2             38.0            40.4
# 5               2823            43.8             42.6            45.0
# 6               2850            43.9             42.7            45.1
# ...              ...             ...              ...             ...
# 12570            140            44.7             43.4            46.1
# 12571            139            44.8             43.3            46.6
# 12573            120            43.5             42.6            44.8
# 12574            115            43.9             43.1            45.3
# 12575            112            44.5             43.6            46.0
#
# [9432 rows x 96 columns]

# %%
year_replacements3 = dict(zip(list(range(2,5)), [f'202{i}-07-01' for i in range(0,4)]))
year_replacements3
# Out:
# {2: '2020-07-01', 3: '2021-07-01', 4: '2022-07-01'}

# %%
for code, date in year_replacements3.items():
    df3['YEAR'] = df3.YEAR.replace(code, date)
df3.head()
# Out:
#        SUMLEV  STATE  COUNTY   STNAME          CTYNAME        YEAR  \
# 1          50      1       1  Alabama   Autauga County  2020-07-01
# 2          50      1       1  Alabama   Autauga County  2021-07-01
# 3          50      1       1  Alabama   Autauga County  2022-07-01
# 5          50      1       3  Alabama   Baldwin County  2020-07-01
# 6          50      1       3  Alabama   Baldwin County  2021-07-01
# ...       ...    ...     ...      ...              ...         ...
# 12570      50     56      43  Wyoming  Washakie County  2021-07-01
# 12571      50     56      43  Wyoming  Washakie County  2022-07-01
# 12573      50     56      45  Wyoming    Weston County  2020-07-01
# 12574      50     56      45  Wyoming    Weston County  2021-07-01
# 12575      50     56      45  Wyoming    Weston County  2022-07-01
#
#        POPESTIMATE  POPEST_MALE  POPEST_FEM  UNDER5_TOT  ...  AGE7579_FEM  \
# 1            58902        28819       30083        3457  ...         1064
# 2            59210        28851       30359        3416  ...         1074
# 3            59759        29105       30654        3460  ...         1152
# 5           233219       114050      119169       12046  ...         4934
# 6           239361       116853      122508       12273  ...         5105
# ...            ...          ...         ...         ...  ...          ...
# 12570         7712         3968        3744         370  ...          171
# 12571         7719         3973        3746         378  ...          187
# 12573         6818         3724        3094         310  ...          110
# 12574         6766         3729        3037         302  ...          115
# 12575         6860         3800        3060         296  ...          127
#
#        AGE8084_TOT  AGE8084_MALE  AGE8084_FEM  AGE85PLUS_TOT  AGE85PLUS_MALE  \
# 1             1170           501          669            958             350
# 2             1190           492          698            972             362
# 3             1225           495          730           1019             385
# 5             5653          2561         3092           4667            1844
# 6             5836          2653         3183           4725            1875
# ...            ...           ...          ...            ...             ...
# 12570          241           117          124            218              78
# 12571          250           125          125            212              73
# 12573          171            70          101            193              73
# 12574          151            66           85            184              69
# 12575          141            71           70            170              58
#
#        AGE85PLUS_FEM  MEDIAN_AGE_TOT  MEDIAN_AGE_MALE  MEDIAN_AGE_FEM
# 1                608            39.1             37.9            40.3
# 2                610            39.2             38.0            40.3
# 3                634            39.2             38.0            40.4
# 5               2823            43.8             42.6            45.0
# 6               2850            43.9             42.7            45.1
# ...              ...             ...              ...             ...
# 12570            140            44.7             43.4            46.1
# 12571            139            44.8             43.3            46.6
# 12573            120            43.5             42.6            44.8
# 12574            115            43.9             43.1            45.3
# 12575            112            44.5             43.6            46.0
#
# [9432 rows x 96 columns]

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9432 entries, 1 to 12575
# Data columns (total 96 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   SUMLEV           9432 non-null   int64
#  1   STATE            9432 non-null   int64
#  2   COUNTY           9432 non-null   int64
#  3   STNAME           9432 non-null   object
#  4   CTYNAME          9432 non-null   object
#  5   YEAR             9432 non-null   object
#  6   POPESTIMATE      9432 non-null   int64
#  7   POPEST_MALE      9432 non-null   int64
#  8   POPEST_FEM       9432 non-null   int64
#  9   UNDER5_TOT       9432 non-null   int64
#  10  UNDER5_MALE      9432 non-null   int64
#  11  UNDER5_FEM       9432 non-null   int64
#  12  AGE513_TOT       9432 non-null   int64
#  13  AGE513_MALE      9432 non-null   int64
#  14  AGE513_FEM       9432 non-null   int64
#  15  AGE1417_TOT      9432 non-null   int64
#  16  AGE1417_MALE     9432 non-null   int64
#  17  AGE1417_FEM      9432 non-null   int64
#  18  AGE1824_TOT      9432 non-null   int64
#  19  AGE1824_MALE     9432 non-null   int64
#  20  AGE1824_FEM      9432 non-null   int64
#  21  AGE16PLUS_TOT    9432 non-null   int64
#  22  AGE16PLUS_MALE   9432 non-null   int64
#  23  AGE16PLUS_FEM    9432 non-null   int64
#  24  AGE18PLUS_TOT    9432 non-null   int64
#  25  AGE18PLUS_MALE   9432 non-null   int64
#  26  AGE18PLUS_FEM    9432 non-null   int64
#  27  AGE1544_TOT      9432 non-null   int64
#  28  AGE1544_MALE     9432 non-null   int64
#  29  AGE1544_FEM      9432 non-null   int64
#  30  AGE2544_TOT      9432 non-null   int64
#  31  AGE2544_MALE     9432 non-null   int64
#  32  AGE2544_FEM      9432 non-null   int64
#  33  AGE4564_TOT      9432 non-null   int64
#  34  AGE4564_MALE     9432 non-null   int64
#  35  AGE4564_FEM      9432 non-null   int64
#  36  AGE65PLUS_TOT    9432 non-null   int64
#  37  AGE65PLUS_MALE   9432 non-null   int64
#  38  AGE65PLUS_FEM    9432 non-null   int64
#  39  AGE04_TOT        9432 non-null   int64
#  40  AGE04_MALE       9432 non-null   int64
#  41  AGE04_FEM        9432 non-null   int64
#  42  AGE59_TOT        9432 non-null   int64
#  43  AGE59_MALE       9432 non-null   int64
#  44  AGE59_FEM        9432 non-null   int64
#  45  AGE1014_TOT      9432 non-null   int64
#  46  AGE1014_MALE     9432 non-null   int64
#  47  AGE1014_FEM      9432 non-null   int64
#  48  AGE1519_TOT      9432 non-null   int64
#  49  AGE1519_MALE     9432 non-null   int64
#  50  AGE1519_FEM      9432 non-null   int64
#  51  AGE2024_TOT      9432 non-null   int64
#  52  AGE2024_MALE     9432 non-null   int64
#  53  AGE2024_FEM      9432 non-null   int64
#  54  AGE2529_TOT      9432 non-null   int64
#  55  AGE2529_MALE     9432 non-null   int64
#  56  AGE2529_FEM      9432 non-null   int64
#  57  AGE3034_TOT      9432 non-null   int64
#  58  AGE3034_MALE     9432 non-null   int64
#  59  AGE3034_FEM      9432 non-null   int64
#  60  AGE3539_TOT      9432 non-null   int64
#  61  AGE3539_MALE     9432 non-null   int64
#  62  AGE3539_FEM      9432 non-null   int64
#  63  AGE4044_TOT      9432 non-null   int64
#  64  AGE4044_MALE     9432 non-null   int64
#  65  AGE4044_FEM      9432 non-null   int64
#  66  AGE4549_TOT      9432 non-null   int64
#  67  AGE4549_MALE     9432 non-null   int64
#  68  AGE4549_FEM      9432 non-null   int64
#  69  AGE5054_TOT      9432 non-null   int64
#  70  AGE5054_MALE     9432 non-null   int64
#  71  AGE5054_FEM      9432 non-null   int64
#  72  AGE5559_TOT      9432 non-null   int64
#  73  AGE5559_MALE     9432 non-null   int64
#  74  AGE5559_FEM      9432 non-null   int64
#  75  AGE6064_TOT      9432 non-null   int64
#  76  AGE6064_MALE     9432 non-null   int64
#  77  AGE6064_FEM      9432 non-null   int64
#  78  AGE6569_TOT      9432 non-null   int64
#  79  AGE6569_MALE     9432 non-null   int64
#  80  AGE6569_FEM      9432 non-null   int64
#  81  AGE7074_TOT      9432 non-null   int64
#  82  AGE7074_MALE     9432 non-null   int64
#  83  AGE7074_FEM      9432 non-null   int64
#  84  AGE7579_TOT      9432 non-null   int64
#  85  AGE7579_MALE     9432 non-null   int64
#  86  AGE7579_FEM      9432 non-null   int64
#  87  AGE8084_TOT      9432 non-null   int64
#  88  AGE8084_MALE     9432 non-null   int64
#  89  AGE8084_FEM      9432 non-null   int64
#  90  AGE85PLUS_TOT    9432 non-null   int64
#  91  AGE85PLUS_MALE   9432 non-null   int64
#  92  AGE85PLUS_FEM    9432 non-null   int64
#  93  MEDIAN_AGE_TOT   9432 non-null   float64
#  94  MEDIAN_AGE_MALE  9432 non-null   float64
#  95  MEDIAN_AGE_FEM   9432 non-null   float64
# dtypes: float64(3), int64(90), object(3)
# memory usage: 7.0+ MB

# %% [markdown]
# ## Concatenating 2000-2009, 2010-2019, and 2020-2022 data

# %%
# The 2000-2010 data has less specificity and therefore fewer columns.
# An outer join will allow the merge and fill the missing columns with NaN.
df = pd.concat([df1, df2, df3], axis=0, join='outer')
df
# Out:
#        SUMLEV  STATE  COUNTY   STNAME          CTYNAME        YEAR  \
# 2          50      1       1  Alabama   Autauga County  2000-07-01
# 3          50      1       1  Alabama   Autauga County  2001-07-01
# 4          50      1       1  Alabama   Autauga County  2002-07-01
# 5          50      1       1  Alabama   Autauga County  2003-07-01
# 6          50      1       1  Alabama   Autauga County  2004-07-01
# ...       ...    ...     ...      ...              ...         ...
# 12570      50     56      43  Wyoming  Washakie County  2021-07-01
# 12571      50     56      43  Wyoming  Washakie County  2022-07-01
# 12573      50     56      45  Wyoming    Weston County  2020-07-01
# 12574      50     56      45  Wyoming    Weston County  2021-07-01
# 12575      50     56      45  Wyoming    Weston County  2022-07-01
#
#       POPESTIMATE POPEST_MALE POPEST_FEM UNDER5_TOT  ... AGE6569_FEM  \
# 2           43872       21318      22554       3027  ...         NaN
# 3           44434       21591      22843       3096  ...         NaN
# 4           45157       21928      23229       3106  ...         NaN
# 5           45762       22222      23540       3110  ...         NaN
# 6           46933       22765      24168       3237  ...         NaN
# ...           ...         ...        ...        ...  ...         ...
# 12570        7712        3968       3744        370  ...         270
# 12571        7719        3973       3746        378  ...         280
# 12573        6818        3724       3094        310  ...         237
# 12574        6766        3729       3037        302  ...         251
# 12575        6860        3800       3060        296  ...         267
#
#       AGE7074_TOT AGE7074_MALE AGE7074_FEM AGE7579_TOT AGE7579_MALE  \
# 2             NaN          NaN         NaN         NaN          NaN
# 3             NaN          NaN         NaN         NaN          NaN
# 4             NaN          NaN         NaN         NaN          NaN
# 5             NaN          NaN         NaN         NaN          NaN
# 6             NaN          NaN         NaN         NaN          NaN
# ...           ...          ...         ...         ...          ...
# 12570         446          220         226         339          168
# 12571         441          215         226         356          169
# 12573         355          190         165         216          106
# 12574         378          209         169         225          110
# 12575         415          231         184         254          127
#
#       AGE7579_FEM AGE8084_TOT AGE8084_MALE AGE8084_FEM
# 2             NaN         NaN          NaN         NaN
# 3             NaN         NaN          NaN         NaN
# 4             NaN         NaN          NaN         NaN
# 5             NaN         NaN          NaN         NaN
# 6             NaN         NaN          NaN         NaN
# ...           ...         ...          ...         ...
# 12570         171         241          117         124
# 12571         187         250          125         125
# 12573         110         171           70         101
# 12574         115         151           66          85
# 12575         127         141           71          70
#
# [72292 rows x 96 columns]

# %%
df = df.reset_index(drop=True)
df.tail()
# Out:
#        SUMLEV  STATE  COUNTY   STNAME          CTYNAME        YEAR  \
# 72287      50     56      43  Wyoming  Washakie County  2021-07-01
# 72288      50     56      43  Wyoming  Washakie County  2022-07-01
# 72289      50     56      45  Wyoming    Weston County  2020-07-01
# 72290      50     56      45  Wyoming    Weston County  2021-07-01
# 72291      50     56      45  Wyoming    Weston County  2022-07-01
#
#       POPESTIMATE POPEST_MALE POPEST_FEM UNDER5_TOT  ... AGE6569_FEM  \
# 72287        7712        3968       3744        370  ...         270
# 72288        7719        3973       3746        378  ...         280
# 72289        6818        3724       3094        310  ...         237
# 72290        6766        3729       3037        302  ...         251
# 72291        6860        3800       3060        296  ...         267
#
#       AGE7074_TOT AGE7074_MALE AGE7074_FEM AGE7579_TOT AGE7579_MALE  \
# 72287         446          220         226         339          168
# 72288         441          215         226         356          169
# 72289         355          190         165         216          106
# 72290         378          209         169         225          110
# 72291         415          231         184         254          127
#
#       AGE7579_FEM AGE8084_TOT AGE8084_MALE AGE8084_FEM
# 72287         171         241          117         124
# 72288         187         250          125         125
# 72289         110         171           70         101
# 72290         115         151           66          85
# 72291         127         141           71          70
#
# [5 rows x 96 columns]

# %% [markdown]
# ### Sorting by year, then state, then county

# %%
df = df.sort_values(['YEAR','STNAME','CTYNAME'])
df
# Out:
#        SUMLEV  STATE  COUNTY   STNAME            CTYNAME        YEAR  \
# 0          50      1       1  Alabama     Autauga County  2000-07-01
# 10         50      1       3  Alabama     Baldwin County  2000-07-01
# 20         50      1       5  Alabama     Barbour County  2000-07-01
# 30         50      1       7  Alabama        Bibb County  2000-07-01
# 40         50      1       9  Alabama      Blount County  2000-07-01
# ...       ...    ...     ...      ...                ...         ...
# 72279      50     56      37  Wyoming  Sweetwater County  2022-07-01
# 72282      50     56      39  Wyoming       Teton County  2022-07-01
# 72285      50     56      41  Wyoming       Uinta County  2022-07-01
# 72288      50     56      43  Wyoming    Washakie County  2022-07-01
# 72291      50     56      45  Wyoming      Weston County  2022-07-01
#
#       POPESTIMATE POPEST_MALE POPEST_FEM UNDER5_TOT  ... AGE6569_FEM  \
# 0           43872       21318      22554       3027  ...         NaN
# 10         141358       69323      72035       8653  ...         NaN
# 20          29035       14969      14066       1781  ...         NaN
# 30          19936        9834      10102       1447  ...         NaN
# 40          51181       25559      25622       3533  ...         NaN
# ...           ...         ...        ...        ...  ...         ...
# 72279       41345       21469      19876       2319  ...        1099
# 72282       23287       12206      11081       1069  ...         674
# 72285       20712       10598      10114       1226  ...         647
# 72288        7719        3973       3746        378  ...         280
# 72291        6860        3800       3060        296  ...         267
#
#       AGE7074_TOT AGE7074_MALE AGE7074_FEM AGE7579_TOT AGE7579_MALE  \
# 0             NaN          NaN         NaN         NaN          NaN
# 10            NaN          NaN         NaN         NaN          NaN
# 20            NaN          NaN         NaN         NaN          NaN
# 30            NaN          NaN         NaN         NaN          NaN
# 40            NaN          NaN         NaN         NaN          NaN
# ...           ...          ...         ...         ...          ...
# 72279        1686          866         820        1014          511
# 72282        1131          628         503         781          387
# 72285         965          506         459         561          306
# 72288         441          215         226         356          169
# 72291         415          231         184         254          127
#
#       AGE7579_FEM AGE8084_TOT AGE8084_MALE AGE8084_FEM
# 0             NaN         NaN          NaN         NaN
# 10            NaN         NaN          NaN         NaN
# 20            NaN         NaN          NaN         NaN
# 30            NaN         NaN          NaN         NaN
# 40            NaN         NaN          NaN         NaN
# ...           ...         ...          ...         ...
# 72279         503         590          287         303
# 72282         394         395          183         212
# 72285         255         316          147         169
# 72288         187         250          125         125
# 72291         127         141           71          70
#
# [72292 rows x 96 columns]

# %% [markdown]
# ### Export to csv

# %%
df.to_csv('county_median_age_2000-2022_raw.csv', index=False)
